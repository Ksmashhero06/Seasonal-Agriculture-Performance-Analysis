# %% [markdown]
# # Seasonal Agriculture Performance Analysis
# Major Data Analytics Project
#
# Domain: Agriculture
# Project Theme: Seasonal Agriculture Performance
# Tools: Python, Pandas, NumPy, Matplotlib Sexbom
# # Project Goal
# Investigine how agriculturni performance verres across senors and identity meaningful pattems ends ons sod differences in the vallable data
# Important: This is a Data Analytics project. No Machine Learning ordement is required

# %% [markdown]
# # Install & Import Libraries

# %%
# Run this first
# !pip -q install scipy seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import f_oneway

plt.style.use("ggplot")
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Upload Dataset

# %%
from google.colab import files

uploaded = files.upload()

df = pd.read_csv("seasonal_agriculture_performance_dataset.csv")

print("Dataset Loaded Successfully!")
print(df.shape)
df.head()
# Out:
#      <input type="file" id="files-0af3ec15-0fd9-4628-b730-795898291e42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0af3ec15-0fd9-4628-b730-795898291e42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Explore Dataset

# %%
print("Rows & Columns:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nDataset Info:")
df.info()

print("\nMissing Values:")
print(df.isnull().sum())

print("\nStatistical Summary:")
display(df.describe())
# Out:
# Rows & Columns: (4000, 28)
#
# Columns:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Remove duplicates
df = df.drop_duplicates()

# Fill missing numeric values
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# Fill missing categorical values
cat_cols = df.select_dtypes(include="object").columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

print("Remaining Missing Values:", df.isnull().sum().sum())
# Out:
# Remaining Missing Values: 0

# %% [markdown]
# # Season Distribution

# %%
plt.figure(figsize=(7,4))

sns.countplot(data=df,
              x="Season",
              order=df["Season"].value_counts().index)

plt.title("Number of Records by Season")
plt.show()

# %% [markdown]
# # Crop Distribution

# %%
plt.figure(figsize=(10,6))

sns.countplot(data=df,
              y="Crop",
              order=df["Crop"].value_counts().index)

plt.title("Crop Distribution")
plt.show()

# %% [markdown]
# # State Distribution

# %%
plt.figure(figsize=(12,5))

sns.countplot(data=df,
              x="State",
              order=df["State"].value_counts().index)

plt.xticks(rotation=90)
plt.title("State-wise Records")
plt.show()

# %% [markdown]
# # Average Yield by Season

# %%
season_yield = df.groupby("Season")["Yield_Tonnes_Ha"].mean().sort_values(ascending=False)

display(season_yield)

season_yield.plot(kind="bar", figsize=(7,4))

plt.ylabel("Yield (Tonnes/Ha)")
plt.title("Average Yield by Season")
plt.show()
# Out:
# Season
# Kharif    5.628612
# Rabi      5.039435
# Zaid      4.641313
# Name: Yield_Tonnes_Ha, dtype: float64

# %% [markdown]
# # Average Profit by Season

# %%
season_profit = df.groupby("Season")["Profit_INR"].mean().sort_values(ascending=False)

display(season_profit)

season_profit.plot(kind="bar", figsize=(7,4))

plt.ylabel("Profit (INR)")
plt.title("Average Profit by Season")
plt.show()
# Out:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %% [markdown]
# # Average Revenue by Season

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(data=df,
                x="Rainfall_mm",
                y="Yield_Tonnes_Ha",
                hue="Season",
                alpha=0.7)

plt.title("Rainfall vs Yield")
plt.show()

# %% [markdown]
# # Rainfall vs Yield

# %%
plt.figure(figsize=(7,4))

sns.barplot(data=df,
            x="Season",
            y="Revenue_INR",
            estimator=np.mean)

plt.title("Average Revenue by Season")
plt.show()

# %% [markdown]
# # Rainfall by Season

# %%
plt.figure(figsize=(7,4))

sns.boxplot(data=df,
            x="Season",
            y="Rainfall_mm")

plt.title("Rainfall Distribution Across Seasons")
plt.show()

# %% [markdown]
# # Temperature by Season

# %%
plt.figure(figsize=(7,4))

sns.boxplot(data=df,
            x="Season",
            y="Avg_Temperature_C")

plt.title("Temperature Across Seasons")
plt.show()

# %% [markdown]
# # Humidity by Season

# %%
plt.figure(figsize=(7,4))

sns.boxplot(data=df,
            x="Season",
            y="Humidity_pct")

plt.title("Humidity Across Seasons")
plt.show()

# %% [markdown]
# # Soil Moisture

# %%
plt.figure(figsize=(7,4))

sns.boxplot(data=df,
            x="Season",
            y="Soil_Moisture_pct")

plt.title("Soil Moisture Across Seasons")
plt.show()

# %% [markdown]
# # Water & Irrigation Analysis

# %%
water = df.groupby("Season")["Water_Efficiency_t_per_1000m3"].mean()

display(water)

water.plot(kind="bar", figsize=(7,4))

plt.title("Water Efficiency by Season")
plt.show()
# Out:
# Season
# Kharif    5.891834
# Rabi      5.186122
# Zaid      4.413239
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %% [markdown]
# # Irrigation Methods

# %%
plt.figure(figsize=(9,5))

sns.countplot(data=df,
              x="Irrigation_Method",
              hue="Season")

plt.xticks(rotation=30)
plt.title("Irrigation Methods Across Seasons")
plt.show()

# %% [markdown]
# # Top Crops by Yield

# %%
top_crop = df.groupby("Crop")["Yield_Tonnes_Ha"].mean().sort_values(ascending=False)

top_crop.plot(kind="bar", figsize=(10,5))

plt.title("Average Yield by Crop")
plt.show()

# %% [markdown]
# # State-wise Profit

# %%
state_profit = df.groupby("State")["Profit_INR"].mean().sort_values(ascending=False)

state_profit.plot(kind="bar", figsize=(12,5))

plt.title("Average Profit by State")
plt.show()

# %% [markdown]
# # Profit Distribution

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Profit_INR"], bins=30, kde=True)

plt.title("Profit Distribution")
plt.show()

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(13,10))

corr = df.select_dtypes(include=np.number).corr()

sns.heatmap(corr,
            cmap="coolwarm",
            center=0)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # ANOVA Test

# %%
groups = [df[df["Season"] == s]["Yield_Tonnes_Ha"] for s in df["Season"].unique()]

F, p = f_oneway(*groups)

print("F-value:", F)
print("P-value:", p)

if p < 0.05:
    print("Result: Significant difference exists between seasons.")
else:
    print("Result: No significant seasonal difference.")
# Out:
# F-value: 1.5438804542488311
# P-value: 0.21367813841792296
# Result: No significant seasonal difference.

# %% [markdown]
# # Best & Worst Performing Seasons

# %%
groups = [df[df["Season"] == s]["Yield_Tonnes_Ha"] for s in df["Season"].unique()]

F, p = f_oneway(*groups)

print("F-value:", F)
print("P-value:", p)

if p < 0.05:
    print("Result: Significant difference exists between seasons.")
else:
    print("Result: No significant seasonal difference.")
# Out:
# F-value: 1.5438804542488311
# P-value: 0.21367813841792296
# Result: No significant seasonal difference.

# %% [markdown]
# # Final Summary Table

# %%
print("Highest Yield Season:", season_yield.idxmax(), round(season_yield.max(),2))

print("Highest Profit Season:", season_profit.idxmax(), round(season_profit.max(),2))

print("Lowest Yield Season:", season_yield.idxmin(), round(season_yield.min(),2))

print("Lowest Profit Season:", season_profit.idxmin(), round(season_profit.min(),2))
# Out:
# Highest Yield Season: Kharif 5.63
# Highest Profit Season: Kharif 178914.65
# Lowest Yield Season: Zaid 4.64
# Lowest Profit Season: Zaid -24804.82

# %% [markdown]
# Download Report

# %%
summary = df.groupby("Season").agg({
    "Yield_Tonnes_Ha":"mean",
    "Profit_INR":"mean",
    "Revenue_INR":"mean",
    "Rainfall_mm":"mean",
    "Avg_Temperature_C":"mean",
    "Humidity_pct":"mean",
    "Soil_Moisture_pct":"mean",
    "Water_Efficiency_t_per_1000m3":"mean"
}).round(2)

display(summary)
# Out:
#         Yield_Tonnes_Ha  Profit_INR  Revenue_INR  Rainfall_mm  \
# Season
# Kharif             5.63   178914.65    710719.06       849.20
# Rabi               5.04    87689.47    601526.05       437.62
# Zaid               4.64   -24804.82    519171.90       304.65
#
#         Avg_Temperature_C  Humidity_pct  Soil_Moisture_pct  \
# Season
# Kharif              28.45         71.81              31.15
# Rabi                23.49         57.89              24.07
# Zaid                31.04         52.01              19.28
#
#         Water_Efficiency_t_per_1000m3
# Season
# Kharif                           5.89
# Rabi                             5.19
# Zaid                             4.41

# %%
summary.to_csv("Seasonal_Agriculture_Summary.csv")

files.download("Seasonal_Agriculture_Summary.csv")
